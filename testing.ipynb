# %% [markdown]
# # Set up

# %%
import numpy as np
import pandas as pd
import streamlit as st
import plotly.express as px


df = pd.read_excel('Workout 2026.xlsx')[:6]
DOW = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
       'Saturday']
DOW
# Out:
# ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# %% [markdown]
# # .xlsx (Depreciated)

# %% [markdown]
# ## Getting the Daily Workouts via .xlsx

# %%
"""
# Initalizing the Workouts_Per_Day dictionary that will be used through other pages
Workouts_Per_Day = {}

# Iterate over the days in the week
for day in DOW:
    
    # Grab the daily excercises
    current_day_excercises = df[day]
    Workouts_Per_Day[day] = []

    # Iterate over the excercises
    for item in current_day_excercises.dropna()[1:]:

        # Ensure it's not a rest day
        if item != "Rest":

            Excercise_df = pd.read_excel('Workout 2026.xlsx', sheet_name=item, index_col=None)
            Excercise_df.drop(['Unnamed: 8', 'Unnamed: 9'], axis=1, inplace=True)
            Excercise_df = Excercise_df[:16]
            Excercise_df.to_csv(f"./Datasets/Excercises/{item}.csv")
            # Load in the Workout from the .xlsx excel sheet named 'item'
            Workouts_Per_Day[day].append(Excercise_df['Excercise Name'][0])

"""
# Out:
# '\n# Initalizing the Workouts_Per_Day dictionary that will be used through other pages\nWorkouts_Per_Day = {}\n\n# Iterate over the days in the week\nfor day in DOW:\n\n    # Grab the daily excercises\n    current_day_excercises = df[day]\n    Workouts_Per_Day[day] = []\n\n    # Iterate over the excercises\n    for item in current_day_excercises.dropna()[1:]:\n\n        # Ensure it\'s not a rest day\n        if item != "Rest":\n\n            Excercise_df = pd.read_excel(\'Workout 2026.xlsx\', sheet_name=item, index_col=None)\n            Excercise_df.drop([\'Unnamed: 8\', \'Unnamed: 9\'], axis=1, inplace=True)\n            Excercise_df = Excercise_df[:16]\n            Excercise_df.to_csv(f"./Datasets/Excercises/{item}.csv")\n            # Load in the Workout from the .xlsx excel sheet named \'item\'\n            Workouts_Per_Day[day].append(Excercise_df[\'Excercise Name\'][0])\n\n'

# %%
"""
for day in Workouts_Per_Day:

    print(Workouts_Per_Day[day])
    curr_day_series = pd.Series(Workouts_Per_Day[day], name=day)
    curr_day_series.to_csv(f"./Datasets/Daily Excercise Series/{day}.csv")

curr_day_series
"""
# Out:
# '\nfor day in Workouts_Per_Day:\n\n    print(Workouts_Per_Day[day])\n    curr_day_series = pd.Series(Workouts_Per_Day[day], name=day)\n    curr_day_series.to_csv(f"./Datasets/Daily Excercise Series/{day}.csv")\n\ncurr_day_series\n'

# %% [markdown]
# ## Getting the Workout's Sheet from the .xlsx file

# %%
"""
day = 'Sunday'
# Excercise Name	Excercise Description	Date	Rest between Sets (Minutes)	Weight (lbs)	Sets (Count)	Reps (Count)	Volume (lbs)

for workout in Workouts_Per_Day[day]:
    day_df = pd.read_excel('Workout 2026.xlsx', sheet_name=workout)
    figure = px.bar(data_frame=day_df, x='Date', y='Volume (lbs)',hover_data=['Date', 'Sets (Count)', 'Reps (Count)','Volume (lbs)'] ,title=day_df['Excercise Name'][1], color='Volume (lbs)', color_continuous_scale=px.colors.sequential.dense)
    figure.show()
    
"""
# Out:
# "\nday = 'Sunday'\n# Excercise Name\tExcercise Description\tDate\tRest between Sets (Minutes)\tWeight (lbs)\tSets (Count)\tReps (Count)\tVolume (lbs)\n\nfor workout in Workouts_Per_Day[day]:\n    day_df = pd.read_excel('Workout 2026.xlsx', sheet_name=workout)\n    figure = px.bar(data_frame=day_df, x='Date', y='Volume (lbs)',hover_data=['Date', 'Sets (Count)', 'Reps (Count)','Volume (lbs)'] ,title=day_df['Excercise Name'][1], color='Volume (lbs)', color_continuous_scale=px.colors.sequential.dense)\n    figure.show()\n\n"

# %% [markdown]
# # .csv (Active file system)

# %%
# Initalizing the Workouts_Per_Day dictionary that will be used through other pages
Workouts_Per_Day = {}

# Iterate over the days in the week
for day in DOW:
    
    # Grab the daily excercises
    current_day_excercises_series = pd.read_csv(f'./Datasets/Daily Excercise Series/{day}.csv')
    Workouts_Per_Day[day] = current_day_excercises_series[day].values.tolist()

Workouts_Per_Day
# Out:
# {'Sunday': ['Bent-Over Barbell Rows',
#   'Overhead Cable Rows',
#   'Table Top Rows (1 armed)',
#   'Single Arm Cable Curls',
#   'Double Arm Cable Curls'],
#  'Monday': ['Push-Ups',
#   'Standing Barbell OHP',
#   'Bent Over Lateral Raises',
#   'Door Frame Goblin'],
#  'Tuesday': ['Squats',
#   'Skull Crushers EZ Bar',
#   'Tricep Overhead Cable',
#   'Tricep Cable Pushdowns'],
#  'Wednesday': [],
#  'Thursday': ['Deadlift',
#   'Cable Face Pulls',
#   'Barbell Shrugs',
#   'EZ-Bar Curls'],
#  'Friday': ['Bench Press',
#   'Inclined Dumbell Press',
#   'Flat Dumbell Flys',
#   'Up-Right Lateral Raises'],
#  'Saturday': ['Glute Press', 'Goblet Squat', 'Tricep Kickback']}

# %%
day = 'Sunday'
# Excercise Name	Excercise Description	Date	Rest between Sets (Minutes)	Weight (lbs)	Sets (Count)	Reps (Count)	Volume (lbs)

for workout in Workouts_Per_Day[day]:
    day_df = pd.read_csv(f'./Datasets/Excercises/{workout}.csv')
    figure = px.bar(data_frame=day_df, x='Date', y='Volume (lbs)',hover_data=['Date', 'Sets (Count)', 'Reps (Count)','Volume (lbs)'] ,title=day_df['Excercise Name'][1], color='Volume (lbs)', color_continuous_scale=px.colors.sequential.dense)
    figure.show()
